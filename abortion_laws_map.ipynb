# %%
import pandas as pd
import folium
import numpy

# %% [markdown]
# Read in a short data table from a CSV file

# %%
ab_by_state_res = pd.read_csv("abortion-rate-by-state-of-residence.csv")
ab_by_state_res
# Out:
#                                          measure_name  datum state_id  \
# 0   Abortion rate (the no. of abortions per 1,000 ...      9       AL
# 1   Abortion rate (the no. of abortions per 1,000 ...     11       AK
# 2   Abortion rate (the no. of abortions per 1,000 ...     10       AZ
# 3   Abortion rate (the no. of abortions per 1,000 ...      8       AR
# 4   Abortion rate (the no. of abortions per 1,000 ...     19       CA
# 5   Abortion rate (the no. of abortions per 1,000 ...     11       CO
# 6   Abortion rate (the no. of abortions per 1,000 ...     19       CT
# 7   Abortion rate (the no. of abortions per 1,000 ...     18       DE
# 8   Abortion rate (the no. of abortions per 1,000 ...     21       DC
# 9   Abortion rate (the no. of abortions per 1,000 ...     20       FL
# 10  Abortion rate (the no. of abortions per 1,000 ...     15       GA
# 11  Abortion rate (the no. of abortions per 1,000 ...     14       HI
# ...

# %% [markdown]
# Select only "datum", "state_id" for choropleth map:   ("state_name" ?)

# %%
data = ab_by_state_res.iloc[:,1:3]

# %%
data.head()
# Out:
#    datum state_id
# 0      9       AL
# 1     11       AK
# 2     10       AZ
# 3      8       AR
# 4     19       CA

# %% [markdown]
# Try following folium documentation choropleth map example *also try basemap and geojson? need to install?

# %%
#folium choropleth map example

url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
state_geo = f'{url}/us-states.json'
#state_unemployment = f'{url}/US_Unemployment_Oct2012.csv'
state_data = data

m = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=state_data,
    columns=['state_id', 'datum'],
#    columns=['State', 'Abortion rate by state of residence (per 1000 women aged 15-44)'], change column name first?
    key_on='feature.id',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Abortion Rate (number of abortions per 1000 women aged 15-44)'
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
